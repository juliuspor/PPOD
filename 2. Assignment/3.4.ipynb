# %% [markdown]
# ## Testing Data Utility - 50 marks
# For this task, we take a closer look at the four different data sets from 3.2 and 3.3:
# - k_anon: Dataset created in 3.2, formed the base for achieving l-diversity and t-closeness
# - l_diverse: Dataset created in 3.2
# - t-close: Dataset created in 3.2
# - cluster: Dataset created in 3.3
#
# Because we used our (in 3.2) created reduced_athletes as the dataset to create all the other datasets, reduced_athletes will be used as the comparison.

# %% [markdown]
# ## 1. The utility of the data
#
# In this task we try to answer the question of how well the data can still be used for its intended purposes compared to the original data.
# In our scenario, we evaluate our anonymized datasets via statistical analysis. Therefore, we design experiments that assess how well the anonymized data preserves the statistical properties of the original data.
#
# 1. We will conduct a statistical comparison of the different data sets we created.
#    1. numerical attributes
#       - mean, median, mode, standard deviation
#       - Cosine Similarity
#    2. categorical attributes
#       - Frequency Table
#       - Jaccard for comparing datasets

# %% [markdown]
# # Numerical Analysis
# ### k_anonymized dataset

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the data
df = pd.read_csv('k_anon.csv')

# Create box plots
plt.figure(figsize=(10, 6))

plt.subplot(1, 3, 1)
sns.boxplot(y=df['age'])
plt.title('Age')

plt.subplot(1, 3, 2)
sns.boxplot(y=df['height'])
plt.title('Height')

plt.subplot(1, 3, 3)
sns.boxplot(y=df['weight'])
plt.title('Weight')

plt.tight_layout()
plt.show()

columns = ['age', 'height', 'weight']

# Calculate and print the statistics
for col in columns:
    mean = df[col].mean()
    median = df[col].median()
    mode = df[col].mode()[0]
    std_dev = df[col].std()

    print(f'{col} statistics:')
    print(f'Mean: {mean}')
    print(f'Median: {median}')
    print(f'Mode: {mode}')
    print(f'Standard Deviation: {std_dev}\n')
# Out:
# age statistics:
# Mean: 30.003542537606307
# Median: 31.33333333333333
# Mode: 0.0
# Standard Deviation: 11.090805360869616
#
# height statistics:
# Mean: 59.21403134623391
# Median: 70.25
# Mode: 0.0
# Standard Deviation: 25.118507647891878
#
# weight statistics:
# Mean: 159.80505810582267
# Median: 182.0
# Mode: 0.0
# Standard Deviation: 70.0753439762375

# %% [markdown]
# ### l_diverse dataset

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the data
df = pd.read_csv('l_diverse.csv')

# Create box plots
plt.figure(figsize=(10, 6))

plt.subplot(1, 3, 1)
sns.boxplot(y=df['age'])
plt.title('Age')

plt.subplot(1, 3, 2)
sns.boxplot(y=df['height'])
plt.title('Height')

plt.subplot(1, 3, 3)
sns.boxplot(y=df['weight'])
plt.title('Weight')

plt.tight_layout()
plt.show()

columns = ['age', 'height', 'weight']

# Calculate and print the statistics
for col in columns:
    mean = df[col].mean()
    median = df[col].median()
    mode = df[col].mode()[0]
    std_dev = df[col].std()

    print(f'{col} statistics:')
    print(f'Mean: {mean}')
    print(f'Median: {median}')
    print(f'Mode: {mode}')
    print(f'Standard Deviation: {std_dev}\n')
# Out:
# age statistics:
# Mean: 30.002844808719928
# Median: 31.33333333333333
# Mode: 0.0
# Standard Deviation: 11.08981996944273
#
# height statistics:
# Mean: 59.20902908901168
# Median: 70.3333333333333
# Mode: 0.0
# Standard Deviation: 25.12133839017027
#
# weight statistics:
# Mean: 159.7954968489307
# Median: 182.0
# Mode: 0.0
# Standard Deviation: 70.04363318102683

# %% [markdown]
# ### t-close dataset

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the data
df = pd.read_csv('t_close.csv')

# Create box plots
plt.figure(figsize=(10, 6))

plt.subplot(1, 3, 1)
sns.boxplot(y=df['age'])
plt.title('Age')

plt.subplot(1, 3, 2)
sns.boxplot(y=df['height'])
plt.title('Height')

plt.subplot(1, 3, 3)
sns.boxplot(y=df['weight'])
plt.title('Weight')

plt.tight_layout()
plt.show()

columns = ['age', 'height', 'weight']

# Calculate and print the statistics
for col in columns:
    mean = df[col].mean()
    median = df[col].median()
    mode = df[col].mode()[0]
    std_dev = df[col].std()

    print(f'{col} statistics:')
    print(f'Mean: {mean}')
    print(f'Median: {median}')
    print(f'Mode: {mode}')
    print(f'Standard Deviation: {std_dev}\n')
# Out:
# age statistics:
# Mean: 30.002844808719928
# Median: 31.33333333333333
# Mode: 0.0
# Standard Deviation: 11.08981996944273
#
# height statistics:
# Mean: 59.20902908901168
# Median: 70.3333333333333
# Mode: 0.0
# Standard Deviation: 25.12133839017027
#
# weight statistics:
# Mean: 159.7954968489307
# Median: 182.0
# Mode: 0.0
# Standard Deviation: 70.04363318102683

# %% [markdown]
# ### clustered dataset

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the data
df = pd.read_csv('cluster.csv')

# Create box plots
plt.figure(figsize=(10, 6))

plt.subplot(1, 3, 1)
sns.boxplot(y=df['age'])
plt.title('Age')

plt.subplot(1, 3, 2)
sns.boxplot(y=df['height'])
plt.title('Height')

plt.subplot(1, 3, 3)
sns.boxplot(y=df['weight'])
plt.title('Weight')

plt.tight_layout()
plt.show()

columns = ['age', 'height', 'weight']

# Calculate and print the statistics
for col in columns:
    mean = df[col].mean()
    median = df[col].median()
    mode = df[col].mode()[0]
    std_dev = df[col].std()

    print(f'{col} statistics:')
    print(f'Mean: {mean}')
    print(f'Median: {median}')
    print(f'Mode: {mode}')
    print(f'Standard Deviation: {std_dev}\n')
# Out:
# age statistics:
# Mean: 20.383100000000002
# Median: 29.041349292709462
# Mode: 0.0021766965428937
# Standard Deviation: 16.67919069056111
#
# height statistics:
# Mean: 34.51559999999999
# Median: 0.5866666666666667
# Mode: 0.0
# Standard Deviation: 35.275048680072445
#
# weight statistics:
# Mean: 94.49284999999999
# Median: 29.7972027972028
# Mode: 0.0
# Standard Deviation: 95.93172516457727

# %% [markdown]
# # Numerical Analysis
# ## Frequency Table
# ### k_anonymized dataset

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the data
df = pd.read_csv('k_anon.csv')

# Calculate frequency table for the 'region' column
frequency_table = df['region'].value_counts()

# Plot the frequency table as a bar chart
frequency_table.plot(kind='bar')

# Add labels and title
plt.xlabel('Region')
plt.ylabel('Frequency')
plt.title('Frequency of Regions')

# Show the plot
plt.show()
print(frequency_table)

# %% [markdown]
# ### l_diverse dataset

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the data
df = pd.read_csv('l_diverse.csv')

# Calculate frequency table for the 'region' column
frequency_table = df['region'].value_counts()

# Plot the frequency table as a bar chart
frequency_table.plot(kind='bar')

# Add labels and title
plt.xlabel('Region')
plt.ylabel('Frequency')
plt.title('Frequency of Regions')

# Show the plot
plt.show()
print(frequency_table)

# %% [markdown]
# ### t_close dataset

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the data
df = pd.read_csv('t_close.csv')

# Calculate frequency table for the 'region' column
frequency_table = df['region'].value_counts()

# Plot the frequency table as a bar chart
frequency_table.plot(kind='bar')

# Add labels and title
plt.xlabel('Region')
plt.ylabel('Frequency')
plt.title('Frequency of Regions')

# Show the plot
plt.show()
print(frequency_table)
# Out:
# region
# North East             3839
# South East             3753
# Mid Atlantic           3488
# North Central          3388
# Southern California    3175
# Australia              3094
# South Central          3031
# Europe                 2986
# Northern California    2482
# South West             2318
# North West             2301
# Central East           2259
# Canada East            1329
# Canada West            1130
# Latin America           702
# Asia                    267
# Africa                  210
# Name: count, dtype: int64

# %% [markdown]
# ### cluster dataset

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the data
df = pd.read_csv('cluster.csv')

# Calculate frequency table for the 'region' column
frequency_table = df['region'].value_counts()

# Plot the frequency table as a bar chart
frequency_table.plot(kind='bar')

# Add labels and title
plt.xlabel('Region')
plt.ylabel('Frequency')
plt.title('Frequency of Regions')

# Show the plot
plt.show()
print(frequency_table)
# Out:
# region
# North East    19714
# Europe          286
# Name: count, dtype: int64

# %% [markdown]
# ## Jaccard similarity Index
# The Jaccard similarity index will be a value between 0 and 1, where 0 indicates no similarity and 1 indicates identical sets.
# ### k_anonymity and raw data

# %%
import pandas as pd

# Load the datasets
raw_data = pd.read_csv('reduced_athletes.csv')
anonymized_data = pd.read_csv('k_anon.csv')

# Assuming 'region' is the column name in both datasets
# Create sets of unique regions from each dataset
raw_regions = set(raw_data['region'].unique())
anonymized_regions = set(anonymized_data['region'].unique())

# Calculate the Jaccard similarity index
intersection = raw_regions.intersection(anonymized_regions)
union = raw_regions.union(anonymized_regions)
jaccard_index = len(intersection) / len(union)

print(f'Jaccard Similarity Index: {jaccard_index}')
# Out:
# Jaccard Similarity Index: 1.0

# %% [markdown]
# ## 2. Comparing the relative utility of the data
# In this task, we compare the four anonymized datasets in regard to their similarities and differences with each other.

# %% [markdown]
# ## Degree of information loss

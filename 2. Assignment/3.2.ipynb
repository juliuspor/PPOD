# %% [markdown]
# ## 3.2 Anonymising your dataset
# Goals: The goal of k-anonymity is to modify a dataset such that any given record cannot be distinguished from at least k−1 other records regarding certain "quasi-identifier" attributes.
#
# quasi-identifiers: 'region', 'gender', 'age', 'height', 'weight', 'eat', 'schedule', 'howlong'

# %%
import pandas as pd

df = pd.read_csv("athletes.csv", index_col=False, low_memory=False)

df['age'].fillna(0, inplace=True)
df['height'].fillna(0, inplace=True)
df['weight'].fillna(0, inplace=True)

df['region'].fillna('', inplace=True)
df['gender'].fillna('', inplace=True)

df.head()
# Out:
#    athlete_id           name               region          team  \
# 0      2554.0      Pj Ablang           South West   Double Edge
# 1      3517.0  Derek Abdella                                NaN
# 2      4691.0            NaN                                NaN
# 3      5164.0    Abo Brandon  Southern California  LAX CrossFit
# 4      5286.0    Bryce Abbey                                NaN
#
#               affiliate gender   age  height  weight   fran  ...  deadlift  \
# 0  Double Edge CrossFit   Male  24.0    70.0   166.0    NaN  ...     400.0
# 1                   NaN   Male  42.0    70.0   190.0    NaN  ...       NaN
# 2                   NaN          0.0     0.0     0.0    NaN  ...       NaN
# 3          LAX CrossFit   Male  40.0    67.0     0.0  211.0  ...     375.0
# 4                   NaN   Male  32.0    65.0   149.0  206.0  ...       NaN
#
#    backsq  pullups                                                eat  \
# 0   305.0      NaN                                                NaN
# 1     NaN      NaN                                                NaN
# 2     NaN      NaN                                                NaN
# 3   325.0     25.0               I eat 1-3 full cheat meals per week|
# 4   325.0     50.0  I eat quality foods but don't measure the amount|
#
#                                                train  \
# 0  I workout mostly at a CrossFit Affiliate|I hav...
# 1  I have a coach who determines my programming|I...
# 2                                                NaN
# 3  I workout mostly at a CrossFit Affiliate|I hav...
# 4  I workout mostly at a CrossFit Affiliate|I inc...
#
#                                           background  \
# 0  I played youth or high school level sports|I r...
# 1        I played youth or high school level sports|
# 2                                                NaN
# 3        I played youth or high school level sports|
# 4                           I played college sports|
#
#                                           experience  \
# 0  I began CrossFit with a coach (e.g. at an affi...
# 1  I began CrossFit with a coach (e.g. at an affi...
# 2                                                NaN
# 3  I began CrossFit by trying it alone (without a...
# 4  I began CrossFit by trying it alone (without a...
#
#                                             schedule     howlong  \
# 0         I do multiple workouts in a day 2x a week|   4+ years|
# 1         I do multiple workouts in a day 2x a week|   4+ years|
# 2                                                NaN         NaN
# 3                 I usually only do 1 workout a day|   4+ years|
# 4  I usually only do 1 workout a day|I strictly s...  1-2 years|
#
#    retrieved_datetime
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
#
# [5 rows x 28 columns]

# %%
def get_spans(df, partition, scale=None):
    """
    Calculates and returns the spans (range of values) for each column in a specified partition of a dataframe, with
    an option to scale these spans by provided values.

    :param        df: the dataframe for which to calculate the spans
    :param partition: the partition for which to calculate the spans
    :param     scale: if given, the spans of each column will be divided
                      by the value in scale for that column
    :returns        : The spans of all columns in the partition
    """
    spans = {}
    for feature_column in quasi_identifiers:
        if feature_column in categorical:
            span = len(df[feature_column][partition].unique())
        else:
            span = df[feature_column][partition].max() - df[feature_column][partition].min()
        if scale is not None:
            span = span / scale[feature_column]
        spans[feature_column] = span
    return spans

# %%
def split(df, partition, column):
    """
    Divides a specified partition of a dataframe into two parts based on the median or unique values of a given column,
    returning a tuple with the indices of these two parts.

    :param        df: The dataframe to split
    :param partition: The partition to split
    :param    column: The column along which to split
    :returns        : A tuple containing a split of the original partition
    """
    dfp = df[column][partition]
    if column in categorical:
        values = dfp.unique()
        lv = set(values[:len(values) // 2])
        rv = set(values[len(values) // 2:])
        return dfp.index[dfp.isin(lv)], dfp.index[dfp.isin(rv)]
    else:
        median = dfp.median()
        dfl = dfp.index[dfp < median]
        dfr = dfp.index[dfp >= median]
        return (dfl, dfr)

# %%
def is_k_anonymous(df, partition, sensitive_column, k=2):
    """
    Checks if a partition is k-anonymous by comparing its amount of entries with the required (k).

    :param               df: The dataframe on which to check the partition.
    :param        partition: The partition of the dataframe to check.
    :param sensitive_column: The name of the sensitive column
    :param                k: The desired k
    :returns               : True if the partition is valid according to our k-anonymity criteria, False otherwise.
    """
    if len(partition) < k:
        return False
    return True

# %%
def partition_dataset(df, feature_columns, sensitive_column, scale, is_valid):
    """
    Partitions a dataframe into valid subsets based on specified feature columns, a sensitive column, and span scales,
    using a validity function to ensure each partition meets certain criteria.

    :param               df: The dataframe to be partitioned.
    :param  feature_columns: A list of column names along which to partition the dataset.
    :param sensitive_column: The name of the sensitive column (to be passed on to the is_valid function)
    :param            scale: The column spans as generated before.
    :param         is_valid: A function that takes a dataframe and a partition and returns True if the partition is valid.
    :returns               : A list of valid partitions that cover the entire dataframe.
    """
    finished_partitions = []
    partitions = [df.index]
    while partitions:
        partition = partitions.pop(0)
        spans = get_spans(df[feature_columns], partition, scale)
        for column, span in sorted(spans.items(), key=lambda x: -x[1]):
            lp, rp = split(df, partition, column)
            if not is_valid(df, lp, sensitive_column) or not is_valid(df, rp, sensitive_column):
                continue
            partitions.extend((lp, rp))
            break
        else:
            finished_partitions.append(partition)
    return finished_partitions

# %%
def agg_categorical_column(series):
    """
    Aggregates the values of a series with categorical values by concatenating them.

    :param           series: A series of categorical values that need to be aggregated.
    :returns               : A string with all the values in the series joined with a ',' (comma).
    """
    series = set(series.astype(str))
    return ','.join(series)
    #return [','.join(series)]

# %%
def agg_numerical_column(series):
    return series.mean()
    #return [series.mean()]

# %%
def build_anonymized_dataset(df, partitions, feature_columns, sensitive_columns,
                                                  max_partitions=None):
    """
    Constructs an anonymized dataset by aggregating feature columns and sensitive columns separately for each partition.

    :param                df: The dataframe to be anonymized.
    :param        partitions: A list of indices for each partition of the dataframe.
    :param   feature_columns: A list of feature column names to aggregate.
    :param sensitive_columns: A list of sensitive column names to aggregate.
    :param    max_partitions: Optional, maximum number of partitions to process.
    :returns                : An anonymized dataframe with aggregated feature and sensitive columns.
    """
    aggregations = {}
    for column in feature_columns:
        if column in categorical:
            aggregations[column] = agg_categorical_column
        else:
            aggregations[column] = agg_numerical_column
    rows = []
    for i, partition in enumerate(partitions):
        if i % 100 == 1:
            print("Finished {} partitions...".format(i))
        if max_partitions is not None and i > max_partitions:
            break
        grouped_columns = df.loc[partition].agg(aggregations, squeeze=False)
        values = grouped_columns.to_dict()
        # Iterate through each sensitive column and aggregate counts
        for sensitive_column in sensitive_columns:
            sensitive_counts = df.loc[partition].groupby(sensitive_column).agg({sensitive_column: 'count'})
            for sensitive_value, count in sensitive_counts[sensitive_column].items():
                if count == 0:
                    continue
                sensitive_values = values.copy()
                sensitive_values.update({
                    sensitive_column: sensitive_value,
                    'count': count,
                })
                rows.append(sensitive_values)
    return pd.DataFrame(rows)

# %%
categorical = {'schedule', 'howlong', 'region', 'gender', 'eat'}

# we apply our partitioning method to two columns of our dataset, using "income" as the sensitive attribute
for name in categorical:
    df[name] = df[name].astype('category')
# Obtain the spans for each column in the dataframe
# quasi-identifiers that should be taken into acount

quasi_identifiers = ['region', 'gender', 'age', 'height', 'weight', 'eat', 'schedule', 'howlong']
# sensitive-values that should be taken into account
sensitive_columns = ['athlete_id', 'fran', 'helen', 'grace', 'filthy50', 'fgonebad', 'run400', 'run5k', 'candj', 'snatch', 'deadlift',
                     'backsq', 'pullups', 'retrieved_datetime']

# %%
full_spans = get_spans(df, df.index)

# %%
finished_partitions = partition_dataset(df, quasi_identifiers, sensitive_columns, full_spans, is_k_anonymous)
len(finished_partitions)
# Out:
# 75326

# %%
dfn = build_anonymized_dataset(df, finished_partitions, quasi_identifiers, sensitive_columns)
# we sort the resulting dataframe using the feature columns and the sensitive attribute
#dfn.sort_values()

dfn.to_csv("k_anon.csv")
# Out:
# Finished 1 partitions...
# Finished 101 partitions...
# Finished 201 partitions...
# Finished 301 partitions...
# Finished 401 partitions...
# Finished 501 partitions...
# Finished 601 partitions...
# Finished 701 partitions...
# Finished 801 partitions...
# Finished 901 partitions...
# Finished 1001 partitions...
# Finished 1101 partitions...
# Finished 1201 partitions...
# Finished 1301 partitions...
# Finished 1401 partitions...
# Finished 1501 partitions...
# Finished 1601 partitions...
# Finished 1701 partitions...
# Finished 1801 partitions...
# Finished 1901 partitions...
# Finished 2001 partitions...
# Finished 2101 partitions...
# Finished 2201 partitions...
# Finished 2301 partitions...
# Finished 2401 partitions...
# Finished 2501 partitions...
# Finished 2601 partitions...
# Finished 2701 partitions...
# Finished 2801 partitions...
# Finished 2901 partitions...
# Finished 3001 partitions...
# Finished 3101 partitions...
# Finished 3201 partitions...
# Finished 3301 partitions...
# Finished 3401 partitions...
# Finished 3501 partitions...
# Finished 3601 partitions...
# Finished 3701 partitions...
# Finished 3801 partitions...
# Finished 3901 partitions...
# Finished 4001 partitions...
# Finished 4101 partitions...
# Finished 4201 partitions...
# Finished 4301 partitions...
# Finished 4401 partitions...
# Finished 4501 partitions...
# Finished 4601 partitions...
# Finished 4701 partitions...
# Finished 4801 partitions...
# Finished 4901 partitions...
# Finished 5001 partitions...
# Finished 5101 partitions...
# Finished 5201 partitions...
# Finished 5301 partitions...
# Finished 5401 partitions...
# Finished 5501 partitions...
# Finished 5601 partitions...
# Finished 5701 partitions...
# Finished 5801 partitions...
# Finished 5901 partitions...
# Finished 6001 partitions...
# Finished 6101 partitions...
# Finished 6201 partitions...
# Finished 6301 partitions...
# Finished 6401 partitions...
# Finished 6501 partitions...
# Finished 6601 partitions...
# Finished 6701 partitions...
# Finished 6801 partitions...
# Finished 6901 partitions...
# Finished 7001 partitions...
# Finished 7101 partitions...
# Finished 7201 partitions...
# Finished 7301 partitions...
# Finished 7401 partitions...
# Finished 7501 partitions...
# Finished 7601 partitions...
# Finished 7701 partitions...
# Finished 7801 partitions...
# Finished 7901 partitions...
# Finished 8001 partitions...
# Finished 8101 partitions...
# Finished 8201 partitions...
# Finished 8301 partitions...
# Finished 8401 partitions...
# Finished 8501 partitions...
# Finished 8601 partitions...
# Finished 8701 partitions...
# Finished 8801 partitions...
# Finished 8901 partitions...
# Finished 9001 partitions...
# Finished 9101 partitions...
# Finished 9201 partitions...
# Finished 9301 partitions...
# Finished 9401 partitions...
# Finished 9501 partitions...
# Finished 9601 partitions...
# Finished 9701 partitions...
# Finished 9801 partitions...
# Finished 9901 partitions...
# Finished 10001 partitions...
# Finished 10101 partitions...
# Finished 10201 partitions...
# Finished 10301 partitions...
# Finished 10401 partitions...
# Finished 10501 partitions...
# Finished 10601 partitions...
# Finished 10701 partitions...
# Finished 10801 partitions...
# Finished 10901 partitions...
# Finished 11001 partitions...
# Finished 11101 partitions...
# Finished 11201 partitions...
# Finished 11301 partitions...
# Finished 11401 partitions...
# Finished 11501 partitions...
# Finished 11601 partitions...
# Finished 11701 partitions...
# Finished 11801 partitions...
# Finished 11901 partitions...
# Finished 12001 partitions...
# Finished 12101 partitions...
# Finished 12201 partitions...
# Finished 12301 partitions...
# Finished 12401 partitions...
# Finished 12501 partitions...
# Finished 12601 partitions...
# Finished 12701 partitions...
# Finished 12801 partitions...
# Finished 12901 partitions...
# Finished 13001 partitions...
# Finished 13101 partitions...
# Finished 13201 partitions...
# Finished 13301 partitions...
# Finished 13401 partitions...
# Finished 13501 partitions...
# Finished 13601 partitions...
# Finished 13701 partitions...
# Finished 13801 partitions...
# Finished 13901 partitions...
# Finished 14001 partitions...
# Finished 14101 partitions...
# Finished 14201 partitions...
# Finished 14301 partitions...
# Finished 14401 partitions...
# Finished 14501 partitions...
# Finished 14601 partitions...
# Finished 14701 partitions...
# Finished 14801 partitions...
# Finished 14901 partitions...
# Finished 15001 partitions...
# Finished 15101 partitions...
# Finished 15201 partitions...
# Finished 15301 partitions...
# Finished 15401 partitions...
# Finished 15501 partitions...
# Finished 15601 partitions...
# Finished 15701 partitions...
# Finished 15801 partitions...
# Finished 15901 partitions...
# Finished 16001 partitions...
# Finished 16101 partitions...
# Finished 16201 partitions...
# Finished 16301 partitions...
# Finished 16401 partitions...
# Finished 16501 partitions...
# Finished 16601 partitions...
# Finished 16701 partitions...
# Finished 16801 partitions...
# Finished 16901 partitions...
# Finished 17001 partitions...
# Finished 17101 partitions...
# Finished 17201 partitions...
# Finished 17301 partitions...
# Finished 17401 partitions...
# Finished 17501 partitions...
# Finished 17601 partitions...
# Finished 17701 partitions...
# Finished 17801 partitions...
# Finished 17901 partitions...
# Finished 18001 partitions...
# Finished 18101 partitions...
# Finished 18201 partitions...
# Finished 18301 partitions...
# Finished 18401 partitions...
# Finished 18501 partitions...
# Finished 18601 partitions...
# Finished 18701 partitions...
# Finished 18801 partitions...
# Finished 18901 partitions...
# Finished 19001 partitions...
# Finished 19101 partitions...
# Finished 19201 partitions...
# Finished 19301 partitions...
# Finished 19401 partitions...
# Finished 19501 partitions...
# Finished 19601 partitions...
# Finished 19701 partitions...
# Finished 19801 partitions...
# Finished 19901 partitions...
# Finished 20001 partitions...
# Finished 20101 partitions...
# Finished 20201 partitions...
# Finished 20301 partitions...
# Finished 20401 partitions...
# Finished 20501 partitions...
# Finished 20601 partitions...
# Finished 20701 partitions...
# Finished 20801 partitions...
# Finished 20901 partitions...
# Finished 21001 partitions...
# Finished 21101 partitions...
# Finished 21201 partitions...
# Finished 21301 partitions...
# Finished 21401 partitions...
# Finished 21501 partitions...
# Finished 21601 partitions...
# Finished 21701 partitions...
# Finished 21801 partitions...
# Finished 21901 partitions...
# Finished 22001 partitions...
# Finished 22101 partitions...
# Finished 22201 partitions...
# Finished 22301 partitions...
# Finished 22401 partitions...
# Finished 22501 partitions...
# Finished 22601 partitions...
# Finished 22701 partitions...
# Finished 22801 partitions...
# Finished 22901 partitions...
# Finished 23001 partitions...
# Finished 23101 partitions...
# Finished 23201 partitions...
# Finished 23301 partitions...
# Finished 23401 partitions...
# Finished 23501 partitions...
# Finished 23601 partitions...
# Finished 23701 partitions...
# Finished 23801 partitions...
# Finished 23901 partitions...
# Finished 24001 partitions...
# Finished 24101 partitions...
# Finished 24201 partitions...
# Finished 24301 partitions...
# Finished 24401 partitions...
# Finished 24501 partitions...
# Finished 24601 partitions...
# Finished 24701 partitions...
# Finished 24801 partitions...
# Finished 24901 partitions...
# Finished 25001 partitions...
# Finished 25101 partitions...
# Finished 25201 partitions...
# Finished 25301 partitions...
# Finished 25401 partitions...
# Finished 25501 partitions...
# Finished 25601 partitions...
# Finished 25701 partitions...
# Finished 25801 partitions...
# Finished 25901 partitions...
# Finished 26001 partitions...
# Finished 26101 partitions...
# Finished 26201 partitions...
# Finished 26301 partitions...
# Finished 26401 partitions...
# Finished 26501 partitions...
# Finished 26601 partitions...
# Finished 26701 partitions...
# Finished 26801 partitions...
# Finished 26901 partitions...
# Finished 27001 partitions...
# Finished 27101 partitions...
# Finished 27201 partitions...
# Finished 27301 partitions...
# Finished 27401 partitions...
# Finished 27501 partitions...
# Finished 27601 partitions...
# Finished 27701 partitions...
# Finished 27801 partitions...
# Finished 27901 partitions...
# Finished 28001 partitions...
# Finished 28101 partitions...
# Finished 28201 partitions...
# Finished 28301 partitions...
# Finished 28401 partitions...
# Finished 28501 partitions...
# Finished 28601 partitions...
# Finished 28701 partitions...
# Finished 28801 partitions...
# Finished 28901 partitions...
# Finished 29001 partitions...
# Finished 29101 partitions...
# Finished 29201 partitions...
# Finished 29301 partitions...
# Finished 29401 partitions...
# Finished 29501 partitions...
# Finished 29601 partitions...
# Finished 29701 partitions...
# Finished 29801 partitions...
# Finished 29901 partitions...
# Finished 30001 partitions...
# Finished 30101 partitions...
# Finished 30201 partitions...
# Finished 30301 partitions...
# Finished 30401 partitions...
# Finished 30501 partitions...
# Finished 30601 partitions...
# Finished 30701 partitions...
# Finished 30801 partitions...
# Finished 30901 partitions...
# Finished 31001 partitions...
# Finished 31101 partitions...
# Finished 31201 partitions...
# Finished 31301 partitions...
# Finished 31401 partitions...
# Finished 31501 partitions...
# Finished 31601 partitions...
# Finished 31701 partitions...
# Finished 31801 partitions...
# Finished 31901 partitions...
# Finished 32001 partitions...
# Finished 32101 partitions...
# Finished 32201 partitions...
# Finished 32301 partitions...
# Finished 32401 partitions...
# Finished 32501 partitions...
# Finished 32601 partitions...
# Finished 32701 partitions...
# Finished 32801 partitions...
# Finished 32901 partitions...
# Finished 33001 partitions...
# Finished 33101 partitions...
# Finished 33201 partitions...
# Finished 33301 partitions...
# Finished 33401 partitions...
# Finished 33501 partitions...
# Finished 33601 partitions...
# Finished 33701 partitions...
# Finished 33801 partitions...
# Finished 33901 partitions...
# Finished 34001 partitions...
# Finished 34101 partitions...
# Finished 34201 partitions...
# Finished 34301 partitions...
# Finished 34401 partitions...
# Finished 34501 partitions...
# Finished 34601 partitions...
# Finished 34701 partitions...
# Finished 34801 partitions...
# Finished 34901 partitions...
# Finished 35001 partitions...
# Finished 35101 partitions...
# Finished 35201 partitions...
# Finished 35301 partitions...
# Finished 35401 partitions...
# Finished 35501 partitions...
# Finished 35601 partitions...
# Finished 35701 partitions...
# Finished 35801 partitions...
# Finished 35901 partitions...
# Finished 36001 partitions...
# Finished 36101 partitions...
# Finished 36201 partitions...
# Finished 36301 partitions...
# Finished 36401 partitions...
# Finished 36501 partitions...
# Finished 36601 partitions...
# Finished 36701 partitions...
# Finished 36801 partitions...
# Finished 36901 partitions...
# Finished 37001 partitions...
# Finished 37101 partitions...
# Finished 37201 partitions...
# Finished 37301 partitions...
# Finished 37401 partitions...
# Finished 37501 partitions...
# Finished 37601 partitions...
# Finished 37701 partitions...
# Finished 37801 partitions...
# Finished 37901 partitions...
# Finished 38001 partitions...
# Finished 38101 partitions...
# Finished 38201 partitions...
# Finished 38301 partitions...
# Finished 38401 partitions...
# Finished 38501 partitions...
# Finished 38601 partitions...
# Finished 38701 partitions...
# Finished 38801 partitions...
# Finished 38901 partitions...
# Finished 39001 partitions...
# Finished 39101 partitions...
# Finished 39201 partitions...
# Finished 39301 partitions...
# Finished 39401 partitions...
# Finished 39501 partitions...
# Finished 39601 partitions...
# Finished 39701 partitions...
# Finished 39801 partitions...
# Finished 39901 partitions...
# Finished 40001 partitions...
# Finished 40101 partitions...
# Finished 40201 partitions...
# Finished 40301 partitions...
# Finished 40401 partitions...
# Finished 40501 partitions...
# Finished 40601 partitions...
# Finished 40701 partitions...
# Finished 40801 partitions...
# Finished 40901 partitions...
# Finished 41001 partitions...
# Finished 41101 partitions...
# Finished 41201 partitions...
# Finished 41301 partitions...
# Finished 41401 partitions...
# Finished 41501 partitions...
# Finished 41601 partitions...
# Finished 41701 partitions...
# Finished 41801 partitions...
# Finished 41901 partitions...
# Finished 42001 partitions...
# Finished 42101 partitions...
# Finished 42201 partitions...
# Finished 42301 partitions...
# Finished 42401 partitions...
# Finished 42501 partitions...
# Finished 42601 partitions...
# Finished 42701 partitions...
# Finished 42801 partitions...
# Finished 42901 partitions...
# Finished 43001 partitions...
# Finished 43101 partitions...
# Finished 43201 partitions...
# Finished 43301 partitions...
# Finished 43401 partitions...
# Finished 43501 partitions...
# Finished 43601 partitions...
# Finished 43701 partitions...
# Finished 43801 partitions...
# Finished 43901 partitions...
# Finished 44001 partitions...
# Finished 44101 partitions...
# Finished 44201 partitions...
# Finished 44301 partitions...
# Finished 44401 partitions...
# Finished 44501 partitions...
# Finished 44601 partitions...
# Finished 44701 partitions...
# Finished 44801 partitions...
# Finished 44901 partitions...
# Finished 45001 partitions...
# Finished 45101 partitions...
# Finished 45201 partitions...
# Finished 45301 partitions...
# Finished 45401 partitions...
# Finished 45501 partitions...
# Finished 45601 partitions...
# Finished 45701 partitions...
# Finished 45801 partitions...
# Finished 45901 partitions...
# Finished 46001 partitions...
# Finished 46101 partitions...
# Finished 46201 partitions...
# Finished 46301 partitions...
# Finished 46401 partitions...
# Finished 46501 partitions...
# Finished 46601 partitions...
# Finished 46701 partitions...
# Finished 46801 partitions...
# Finished 46901 partitions...
# Finished 47001 partitions...
# Finished 47101 partitions...
# Finished 47201 partitions...
# Finished 47301 partitions...
# Finished 47401 partitions...
# Finished 47501 partitions...
# Finished 47601 partitions...
# Finished 47701 partitions...
# Finished 47801 partitions...
# Finished 47901 partitions...
# Finished 48001 partitions...
# Finished 48101 partitions...
# Finished 48201 partitions...
# Finished 48301 partitions...
# Finished 48401 partitions...
# Finished 48501 partitions...
# Finished 48601 partitions...
# Finished 48701 partitions...
# Finished 48801 partitions...
# Finished 48901 partitions...
# Finished 49001 partitions...
# Finished 49101 partitions...
# Finished 49201 partitions...
# Finished 49301 partitions...
# Finished 49401 partitions...
# Finished 49501 partitions...
# Finished 49601 partitions...
# Finished 49701 partitions...
# Finished 49801 partitions...
# Finished 49901 partitions...
# Finished 50001 partitions...
# Finished 50101 partitions...
# Finished 50201 partitions...
# Finished 50301 partitions...
# Finished 50401 partitions...
# Finished 50501 partitions...
# Finished 50601 partitions...
# Finished 50701 partitions...
# Finished 50801 partitions...
# Finished 50901 partitions...
# Finished 51001 partitions...
# Finished 51101 partitions...
# Finished 51201 partitions...
# Finished 51301 partitions...
# Finished 51401 partitions...
# Finished 51501 partitions...
# Finished 51601 partitions...
# Finished 51701 partitions...
# Finished 51801 partitions...
# Finished 51901 partitions...
# Finished 52001 partitions...
# Finished 52101 partitions...
# Finished 52201 partitions...
# Finished 52301 partitions...
# Finished 52401 partitions...
# Finished 52501 partitions...
# Finished 52601 partitions...
# Finished 52701 partitions...
# Finished 52801 partitions...
# Finished 52901 partitions...
# Finished 53001 partitions...
# Finished 53101 partitions...
# Finished 53201 partitions...
# Finished 53301 partitions...
# Finished 53401 partitions...
# Finished 53501 partitions...
# Finished 53601 partitions...
# Finished 53701 partitions...
# Finished 53801 partitions...
# Finished 53901 partitions...
# Finished 54001 partitions...
# Finished 54101 partitions...
# Finished 54201 partitions...
# Finished 54301 partitions...
# Finished 54401 partitions...
# Finished 54501 partitions...
# Finished 54601 partitions...
# Finished 54701 partitions...
# Finished 54801 partitions...
# Finished 54901 partitions...
# Finished 55001 partitions...
# Finished 55101 partitions...
# Finished 55201 partitions...
# Finished 55301 partitions...
# Finished 55401 partitions...
# Finished 55501 partitions...
# Finished 55601 partitions...
# Finished 55701 partitions...
# Finished 55801 partitions...
# Finished 55901 partitions...
# Finished 56001 partitions...
# Finished 56101 partitions...
# Finished 56201 partitions...
# Finished 56301 partitions...
# Finished 56401 partitions...
# Finished 56501 partitions...
# Finished 56601 partitions...
# Finished 56701 partitions...
# Finished 56801 partitions...
# Finished 56901 partitions...
# Finished 57001 partitions...
# Finished 57101 partitions...
# Finished 57201 partitions...
# Finished 57301 partitions...
# Finished 57401 partitions...
# Finished 57501 partitions...
# Finished 57601 partitions...
# Finished 57701 partitions...
# Finished 57801 partitions...
# Finished 57901 partitions...
# Finished 58001 partitions...
# Finished 58101 partitions...
# Finished 58201 partitions...
# Finished 58301 partitions...
# Finished 58401 partitions...
# Finished 58501 partitions...
# Finished 58601 partitions...
# Finished 58701 partitions...
# Finished 58801 partitions...
# Finished 58901 partitions...
# Finished 59001 partitions...
# Finished 59101 partitions...
# Finished 59201 partitions...
# Finished 59301 partitions...
# Finished 59401 partitions...
# Finished 59501 partitions...
# Finished 59601 partitions...
# Finished 59701 partitions...
# Finished 59801 partitions...
# Finished 59901 partitions...
# Finished 60001 partitions...
# Finished 60101 partitions...
# Finished 60201 partitions...
# Finished 60301 partitions...
# Finished 60401 partitions...
# Finished 60501 partitions...
# Finished 60601 partitions...
# Finished 60701 partitions...
# Finished 60801 partitions...
# Finished 60901 partitions...
# Finished 61001 partitions...
# Finished 61101 partitions...
# Finished 61201 partitions...
# Finished 61301 partitions...
# Finished 61401 partitions...
# Finished 61501 partitions...
# Finished 61601 partitions...
# Finished 61701 partitions...
# Finished 61801 partitions...
# Finished 61901 partitions...
# Finished 62001 partitions...
# Finished 62101 partitions...
# Finished 62201 partitions...
# Finished 62301 partitions...
# Finished 62401 partitions...
# Finished 62501 partitions...
# Finished 62601 partitions...
# Finished 62701 partitions...
# Finished 62801 partitions...
# Finished 62901 partitions...
# Finished 63001 partitions...
# Finished 63101 partitions...
# Finished 63201 partitions...
# Finished 63301 partitions...
# Finished 63401 partitions...
# Finished 63501 partitions...
# Finished 63601 partitions...
# Finished 63701 partitions...
# Finished 63801 partitions...
# Finished 63901 partitions...
# Finished 64001 partitions...
# Finished 64101 partitions...
# Finished 64201 partitions...
# Finished 64301 partitions...
# Finished 64401 partitions...
# Finished 64501 partitions...
# Finished 64601 partitions...
# Finished 64701 partitions...
# Finished 64801 partitions...
# Finished 64901 partitions...
# Finished 65001 partitions...
# Finished 65101 partitions...
# Finished 65201 partitions...
# Finished 65301 partitions...
# Finished 65401 partitions...
# Finished 65501 partitions...
# Finished 65601 partitions...
# Finished 65701 partitions...
# Finished 65801 partitions...
# Finished 65901 partitions...
# Finished 66001 partitions...
# Finished 66101 partitions...
# Finished 66201 partitions...
# Finished 66301 partitions...
# Finished 66401 partitions...
# Finished 66501 partitions...
# Finished 66601 partitions...
# Finished 66701 partitions...
# Finished 66801 partitions...
# Finished 66901 partitions...
# Finished 67001 partitions...
# Finished 67101 partitions...
# Finished 67201 partitions...
# Finished 67301 partitions...
# Finished 67401 partitions...
# Finished 67501 partitions...
# Finished 67601 partitions...
# Finished 67701 partitions...
# Finished 67801 partitions...
# Finished 67901 partitions...
# Finished 68001 partitions...
# Finished 68101 partitions...
# Finished 68201 partitions...
# Finished 68301 partitions...
# Finished 68401 partitions...
# Finished 68501 partitions...
# Finished 68601 partitions...
# Finished 68701 partitions...
# Finished 68801 partitions...
# Finished 68901 partitions...
# Finished 69001 partitions...
# Finished 69101 partitions...
# Finished 69201 partitions...
# Finished 69301 partitions...
# Finished 69401 partitions...
# Finished 69501 partitions...
# Finished 69601 partitions...
# Finished 69701 partitions...
# Finished 69801 partitions...
# Finished 69901 partitions...
# Finished 70001 partitions...
# Finished 70101 partitions...
# Finished 70201 partitions...
# Finished 70301 partitions...
# Finished 70401 partitions...
# Finished 70501 partitions...
# Finished 70601 partitions...
# Finished 70701 partitions...
# Finished 70801 partitions...
# Finished 70901 partitions...
# Finished 71001 partitions...
# Finished 71101 partitions...
# Finished 71201 partitions...
# Finished 71301 partitions...
# Finished 71401 partitions...
# Finished 71501 partitions...
# Finished 71601 partitions...
# Finished 71701 partitions...
# Finished 71801 partitions...
# Finished 71901 partitions...
# Finished 72001 partitions...
# Finished 72101 partitions...
# Finished 72201 partitions...
# Finished 72301 partitions...
# Finished 72401 partitions...
# Finished 72501 partitions...
# Finished 72601 partitions...
# Finished 72701 partitions...
# Finished 72801 partitions...
# Finished 72901 partitions...
# Finished 73001 partitions...
# Finished 73101 partitions...
# Finished 73201 partitions...
# Finished 73301 partitions...
# Finished 73401 partitions...
# Finished 73501 partitions...
# Finished 73601 partitions...
# Finished 73701 partitions...
# Finished 73801 partitions...
# Finished 73901 partitions...
# Finished 74001 partitions...
# Finished 74101 partitions...
# Finished 74201 partitions...
# Finished 74301 partitions...
# Finished 74401 partitions...
# Finished 74501 partitions...
# Finished 74601 partitions...
# Finished 74701 partitions...
# Finished 74801 partitions...
# Finished 74901 partitions...
# Finished 75001 partitions...
# Finished 75101 partitions...
# Finished 75201 partitions...
# Finished 75301 partitions...
